# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
import yt_dlp

youtube_url = input("Enter YouTube URL: ")

# -------------------------------
# Method 1 : Normal extraction
# -------------------------------
method1_opts = {
    'format': 'bestaudio/best',
    'outtmpl': 'audio.%(ext)s',
}

# -------------------------------
# Method 2 : Android fallback
# -------------------------------
method2_opts = {
    'format': 'bestaudio/best',
    'outtmpl': 'audio.%(ext)s',
    'extractor_args': {
        'youtube': {
            'player_client': ['android']
        }
    }
}

try:
    print("\nTrying Method 1 (Normal Extraction)...\n")

    with yt_dlp.YoutubeDL(method1_opts) as ydl:
        ydl.download([youtube_url])

    print("\nAudio downloaded successfully using Method 1!")

except Exception as e:

    print("\nMethod 1 failed!")
    print("Error:", e)

    print("\nTrying Method 2 (Android Fallback)...\n")

    try:
        with yt_dlp.YoutubeDL(method2_opts) as ydl:
            ydl.download([youtube_url])

        print("\nAudio downloaded successfully using Method 2!")

    except Exception as e2:

        print("\nMethod 2 also failed!")
        print("Error:", e2)

        print("\nCould not extract audio from this URL.")
# Out:
# Enter YouTube URL:  https://www.youtube.com/watch?v=vLIyGsbRkmY
# Trying Method 1 (Normal Extraction)...
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vLIyGsbRkmY
# [youtube] vLIyGsbRkmY: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] vLIyGsbRkmY: Downloading android vr player API JSON
# ERROR: [youtube] vLIyGsbRkmY: This video is not available
# Method 1 failed!
# Error: ERROR: [youtube] vLIyGsbRkmY: This video is not available
#
# Trying Method 2 (Android Fallback)...
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vLIyGsbRkmY
# [youtube] vLIyGsbRkmY: Downloading webpage
# [youtube] vLIyGsbRkmY: Downloading android player API JSON
# WARNING: [youtube] vLIyGsbRkmY: android client https formats require a GVS PO Token which was not provided. They will be skipped as they may yield HTTP Error 403. You can manually pass a GVS PO Token for this client with --extractor-args "youtube:po_token=android.gvs+XXX". For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/PO-Token-Guide
# [info] vLIyGsbRkmY: Downloading 1 format(s): 18
# [download] audio.mp4 has already been downloaded
# [download] 100% of    1.80MiB
#
# Audio downloaded successfully using Method 2!

# %%
import whisper
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

model = whisper.load_model("large-v3").to(device)

result = model.transcribe(
    "audio.mp4",
    fp16=True,
    beam_size=5,
    best_of=5,
    temperature=(0.0, 0.2, 0.4)
)

print("Detected language:", result["language"])

with open("audio.txt", "w", encoding="utf-8") as f:
    f.write(result["text"])

print("Transcript saved!")
# Out:
# Using device: cuda
# Detected language: hi
# Transcript saved!
